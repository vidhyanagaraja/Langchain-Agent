# %%
import os 
import certifi 
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
# from langchain import hub
from langchain.tools import tool
import requests
# Out:
# /tmp/ipykernel_4495/2515684740.py:6: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults

# %%
from langchain.agents import create_agent

from langchain_anthropic import ChatAnthropic
model = ChatAnthropic(model="claude-sonnet-4-5")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 3
#       1 from langchain.agents import create_agent
# ----> 3 from langchain_anthropic import ChatAnthropic
#       4 model = ChatAnthropic(model="claude-sonnet-4-5")
#
# ModuleNotFoundError: No module named 'langchain_anthropic'

# %%
ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")
TAVILY_API_KEY =  os.getenv("TAVILY_API_KEY")
WEATHERSTACK_API_KEY = os.getenv("WEATHERSTACK_API_KEY")

# %%
# Out:
#   Cell In[21], line 1
#     -----------------------------------------------------------------------
#                                                                            ^
# SyntaxError: invalid syntax
